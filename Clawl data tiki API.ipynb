q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
    'Referer': 'https://tiki.vn/nha-sach-tiki/c8322',
    'X-Access-Token': 'eyJhbGciOiJSUzI1NiJ9..Jboh37Slaz_lu3_NBdPfIKcAnb7CFj1K5PWkM8Nu32lXHRm21T-SCdTisTzIpNk1WNkBSpdNets-qTGoWmCIDLtH3LfwiQjfa0Yr6Vg0eRP_sFLhMEMpMizJodOcetFLuHyyDSV3O2lBQnLyAbM4wBnuThiKw_Kwtr9rgVD3p_yrPSW70_ixMan7EPSZGEMuAb54PXfy5G9YKbJQgKqWOGLQAoL9fMZFcGfU_C3pNbfrN30t-LAikc3qWIn5GyD7tEUlF5fkj8DE_kO3LSUsI4Oh0FuoE7PWpoojCNsURAZ2SeJxgAfq-lpbJdvUddS1suao8EcxJF4C2bJu0kNvsRn-VLDh8Ar7MU5xitZqhj_3NfvuFuSThJj-3KvOzWlHntAUtiRkpcFy-lp_7zhkcMttuY04F8hPBYCdfzx_nfKihXPS-8CAHdQ2R4MRvNwc1PCc13-3QYCPsK7a0k_FdlyGFpTxVM6-nTGzo0dU4Gv_-pKSXE616eHoWIH2OP-xLmf4MttPT7CWvqzZp12P6Zi8n9HElAYbxym2bGtoYTEbPcCXYWAtnWnmwxRyE1LnxfLXOJg3_rMftWMZoKxQbK_7v-ijvEougsMuDL4xUEL1w-IVqzD2thBSjEGyqXiMG6UDfKQLbUTolCwdcy2fU4AVPfP4qE5e0lJeef-nxZY',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
}

# %%
params = {
    'limit': '10',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': '1896401f-f641-c95f-ebd5-e0f82bd7d53d',
    'category': '8322',
    'urlKey':  'nha-sach-tiki',
}

# %%
product_id = []
for i in range(1, 6):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings', headers=headers, params=params,cookies=cookies)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
last_product_id = []
a=[last_product_id.append(x) for x in product_id if x not in last_product_id]
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
result = []
for pid in last_product_id:
    response = requests.get(f'https://tiki.vn/api/v2/products/{pid["id"]}', headers=headers,cookies=cookies)
    if response.status_code == 200:
        print('Crawl data {} success !!!'.format(pid))
        result.append(response.json())
# Out:
# Crawl data {'id': 192048665} success !!!
# Crawl data {'id': 275016991} success !!!
# Crawl data {'id': 207968695} success !!!
# Crawl data {'id': 207256575} success !!!
# Crawl data {'id': 162205263} success !!!
# Crawl data {'id': 74021317} success !!!
# Crawl data {'id': 188940817} success !!!
# Crawl data {'id': 189643105} success !!!
# Crawl data {'id': 26114399} success !!!
# Crawl data {'id': 109017985} success !!!
# Crawl data {'id': 203231461} success !!!
# Crawl data {'id': 275020957} success !!!
# Crawl data {'id': 77403145} success !!!
# Crawl data {'id': 206308040} success !!!
# Crawl data {'id': 185242031} success !!!
# Crawl data {'id': 174301838} success !!!
# Crawl data {'id': 52789367} success !!!
# Crawl data {'id': 69764541} success !!!
# Crawl data {'id': 174444163} success !!!
# Crawl data {'id': 73207240} success !!!
# Crawl data {'id': 121635154} success !!!
# Crawl data {'id': 147920903} success !!!
# Crawl data {'id': 3954355} success !!!
# ...

# %%
product_data = pd.DataFrame(result)
product_data
# Out:
#            id  master_id            sku  \
# 0   192048665  192048665  6421911853118
# 1   275016991  275016991  9982338551406
# 2   207968695  207968695  1336876385584
# 3   207256575  207256575  1888647655871
# 4   162205263  162205263  2476958235572
# 5    74021317   74021317  5977911599303
# 6   188940817  188940817  8460723711989
# 7   189643105  189643105  7150413107642
# 8    26114399   26114399  6851692325469
# 9   109017985  109017985  8741635599269
# 10  203231461  203231461  6141929863145
# 11  275020957  275020957  9725700192855
# 12   77403145   77403145  8730924452708
# 13  206308040  206308040  4903328995568
# 14  185242031  185242031  5875551825499
# 15  174301838  174301838  5623982635450
# 16   52789367   52789367  5279951395588
# 17   69764541   69764541  9554778221279
# 18  174444163  174444163  8940996830246
# 19   73207240   73207240  8787420605399
# 20  121635154  121635154  7794004489041
# 21  147920903  147920903  1967959392540
# ...

# %%
params_review = {
    'sort': 'score|desc,id|desc,stars|all',
    'limit': '10',
    'include': 'comments'
}

# %%
result1 = []
for pid in last_product_id:
    params_review['product_id'] = pid["id"]
    print('Crawl comment for product {}'.format(pid))
    for i in range(1,4):
        params_review['page'] = i
        response = requests.get('https://tiki.vn/api/v2/reviews', headers=headers, params=params_review,cookies=cookies)
        if response.status_code == 200:
            print('Crawl comment page {} success!!!'.format(i))
            data = response.json().get('data')
            for y in range(len(data)):
                result1.append(data[y])
# Out:
# Crawl comment for product {'id': 192048665}
# Crawl comment page 1 success!!!
# Crawl comment page 2 success!!!
# Crawl comment page 3 success!!!
# Crawl comment for product {'id': 275016991}
# Crawl comment page 1 success!!!
# Crawl comment page 2 success!!!
# Crawl comment page 3 success!!!
# Crawl comment for product {'id': 207968695}
# Crawl comment page 1 success!!!
# Crawl comment page 2 success!!!
# Crawl comment page 3 success!!!
# Crawl comment for product {'id': 207256575}
# Crawl comment page 1 success!!!
# Crawl comment page 2 success!!!
# Crawl comment page 3 success!!!
# Crawl comment for product {'id': 162205263}
# Crawl comment page 1 success!!!
# Crawl comment page 2 success!!!
# Crawl comment page 3 success!!!
# Crawl comment for product {'id': 74021317}
# Crawl comment page 1 success!!!
# Crawl comment page 2 success!!!
# Crawl comment page 3 success!!!
# Crawl comment for product {'id': 188940817}
# Crawl comment page 1 success!!!
# ...

# %%
comment_data = pd.DataFrame(result1)
comment_data
# Out:
#             id            title  \
# 0     19366027         Hài lòng
# 1     18228275  Cực kì hài lòng
# 2     18728334  Cực kì hài lòng
# 3     18367610  Cực kì hài lòng
# 4     19757930  Cực kì hài lòng
# ...        ...              ...
# 1730  17078615  Cực kì hài lòng
# 1731  17309305         Hài lòng
# 1732  17093163  Cực kì hài lòng
# 1733  13044093  Cực kì hài lòng
# 1734  17992326         Hài lòng
#
#                                                 content    status  \
# 0     sách in màu hình minh hoạ đầy đủ dễ hiểu, bìa ...  approved
# 1     Sách đẹp, giao hàng nhanh. Mua 2 quyển lúc giả...  approved
# 2     Sách hình thức tốt, nội dung hay, dịch vụ Tiki...  approved
# 3            Giải thích nội dung trong sách khá dễ hiểu  approved
# 4        Nhiều hình ảnh minh hoạ, rất dễ hiểu và bổ ích  approved
# ...                                                 ...       ...
# 1730  Fahasa giao hàng cực nhanh, sách được bọc mút ...  approved
# ...

# %%
product_data.to_csv('D:/Clawl data/book_tiki.csv', index=False)
comment_data.to_csv('D:/Clawl data/comment_book_tiki.csv', index=False)
